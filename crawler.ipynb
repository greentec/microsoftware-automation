# %%
from bs4 import BeautifulSoup
from selenium import webdriver

options = webdriver.ChromeOptions()

driver = webdriver.Chrome('./chromedriver.exe')
driver.implicitly_wait(3)


# 로그인
url = 'http://127.0.0.1/redmine/login'
driver.get(url)

# 여기에 자신의 레드마인 ID와 패스워드를 입력한다.
driver.find_element_by_name('username').send_keys('USER_ID')
driver.find_element_by_name('password').send_keys('USER_PASSWORD')
driver.find_element_by_name('login').click()


# 구성원과 팀 찾기
profile = {}
team_list = []

url = 'http://127.0.0.1/redmine/projects/automation_demo'
driver.get(url)

html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

members_box_element = soup.select('div[class*="members"]')[0]
members_element = members_box_element.select('a')
for element in members_element:
    member, team = element.text.split(' ')
    member_url = element.get('href')
    member_url = member_url.split('/')[-1]
    if team not in team_list:
        team_list.append(team)
    profile[member_url] = {'name': member, 'team': team}
    
print(profile)
print()


# 진행 일감
import math
import time

issues = {}

url = 'http://127.0.0.1/redmine/projects/automation_demo/issues'
driver.get(url)
html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

# 진행 일감의 총 페이지 수 찾기
items_in_one_page = 25
total_elem = soup.select('span[class="items"]')[0]
max_items = total_elem.text.replace('(','').replace(')','').split('/')[-1]
max_page = math.ceil(int(max_items) / items_in_one_page)

page_url_base = 'http://127.0.0.1/redmine/projects/automation_demo/issues?page='
for page_num in range(1, max_page+1):
    url = page_url_base + str(page_num) + '&per_page=' + str(items_in_one_page)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    
    # 일감 제목 찾기
    subject_elems = soup.select('td[class="subject"]')
    # 일감 담당자 찾기
    assigned_elems = soup.select('td[class="assigned_to"]')
    for idx, subject in enumerate(subject_elems):
        assigned_elem = assigned_elems[idx]
        href = assigned_elem.select('a')[0].get('href')
        href = href.split('/')[-1]
        if href not in profile:
            continue
        # 링크로 구성원을 찾음
        user = profile[href]
        subject_text = subject.select('a')[0].text
        subject_no = subject.select('a')[0].get('href').split('/')[-1]

        # 일감을 팀 별로 분류
        if user['team'] not in issues:
            issues[user['team']] = []
        issues[user['team']].append([int(subject_no), subject_text, user['name'], '진행'])

    time.sleep(1)

print()


# 상위 일감/하위 일감 구조 탐색
graph = {}

for team in team_list:
    print(team)
    if team in issues:
        for issue in issues[team]:
            url = 'http://127.0.0.1/redmine/issues/' + str(issue[0])
            driver.get(url)
            html = driver.page_source
            soup = BeautifulSoup(html, 'lxml')

            # 일감의 위쪽에 있는 상위-하위 일감 리스트 div 를 불러온다.
            subject = soup.select('div[class="subject"]')
            if len(subject) == 0:
                continue
            subject = subject[0]

            titles = subject.div.select('a')
            issue_no_list = []
            for title in titles:
                issue_no = int(title.get('href').split('/')[-1])
                issue_no_list.append(issue_no)
            issue_no_list.append(issue[0])
            issue_no_list = [int(x) for x in issue_no_list]

            # 상위 일감/하위 일감 관계를 저장한다.
            for i in range(len(issue_no_list) - 1):
                if issue_no_list[i] not in graph:
                    graph[issue_no_list[i]] = []
                if issue_no_list[i+1] not in graph[issue_no_list[i]]:
                    graph[issue_no_list[i]].append(issue_no_list[i+1])

            time.sleep(0.01)

print(graph)
print()


# 상위 일감/하위 일감 구조 탐색
# 보여줄 일감 목록. 최상위 일감으로만 구성된다.
show_dict = {}
for team in team_list:
    show_dict[team] = []
    if team in issues:
        for issue in issues[team]:
            show_dict[team].append(int(issue[0]))

# 최상위 일감이 아닌 일감 목록
delete_dict = {}
for team in team_list:
    delete_dict[team] = []

# 상위 일감의 하위 일감이 같은 팀에 있을 때에만 하위 일감을 show_dict 에서 지운다.
for team in show_dict:
    for issue in show_dict[team]:
        if issue in graph:
            for sub_issue in graph[issue]:
                if sub_issue in show_dict[team]:
                    if sub_issue not in delete_dict[team]:
                        delete_dict[team].append(sub_issue)

for team in delete_dict:
    for issue in delete_dict[team]:
        show_dict[team].remove(issue)

print(delete_dict)
print(show_dict)
print()


# 템플릿 텍스트 생성
import html
from jinja2 import Template
show_team_list = ['시스템기획', '콘텐츠기획', '밸런스기획', '클라이언트프로그래밍', '서버프로그래밍']

template = Template(u'''\
{%- macro dump_sub_issues(indexes, team) %}
  <ul>
    {% for idx in indexes %}
      {% if idx not in show_dict[team] %}
        {% for issue in issues[team] %}
          {% if issue[0] == idx %}
            <li><a href="http://127.0.0.1/redmine/issues/{{issue[0]}}">#{{ issue[0] }}</a> {{ html.escape(issue[1]) }} ({{ issue[-1] }})</li>
            {% if issue[0] in graph %}
              {% call dump_sub_issues(graph[issue[0]], team) %}
              {% endcall %}
            {% endif %}
          {% endif %}
        {% endfor %}
      {% endif %}
    {% endfor %}
  </ul>
  {{ caller() }}
{%- endmacro %}
<h2>
  <strong>➢ 팀별 금주 주간 업무</strong>
</h2>
<ul>
  {%- for team in show_team_list %}
    <li>
      <p>{{ team }}</p>
      <ul>
        {%- for issue in issues[team] %}
          {% if issue[0] in show_dict[team] %}
            <li><a href="http://127.0.0.1/redmine/issues/{{issue[0]}}">#{{ issue[0] }}</a> {{ html.escape(issue[1]) }} ({{ issue[-1] }})</li>
            {% if issue[0] in graph %}
              {% call dump_sub_issues(graph[issue[0]], team) %}
              {% endcall %}
            {% endif %}
          {% endif %}
        {% endfor %}
      </ul>
    </li>
  {%- endfor %}
</ul>

''')

s = template.render(show_team_list=show_team_list,
                    issues=issues,
                    html=html,
                    graph=graph,
                    show_dict=show_dict)

import re
s = re.sub('\n', '', s)
s = re.sub(' +', ' ', s)

print(s)
# Out:
# {'25': {'name': '구연기', 'team': '서버프로그래밍'}, '17': {'name': '반규린', 'team': '콘텐츠기획'}, '5': {'name': '백무연', 'team': '시스템기획'}, '23': {'name': '서달수', 'team': '시스템기획'}, '21': {'name': '유화영', 'team': '밸런스기획'}, '22': {'name': '이인성', 'team': '클라이언트프로그래밍'}, '19': {'name': '이해은', 'team': '서버프로그래밍'}, '18': {'name': '임파초', 'team': '클라이언트프로그래밍'}, '20': {'name': '장인목', 'team': '시스템기획'}, '24': {'name': '진미화', 'team': '콘텐츠기획'}}
#
#
# 서버프로그래밍
# 콘텐츠기획
# 시스템기획
# 밸런스기획
# 클라이언트프로그래밍
# {14: [17, 18, 16], 17: [46], 7: [38, 37, 36], 32: [35, 34, 33], 30: [49, 48], 11: [13, 12], 13: [24, 23], 12: [20, 19], 50: [52, 53], 52: [55], 53: [54], 8: [10, 9], 3: [28, 27, 26]}
#
# {'서버프로그래밍': [], '콘텐츠기획': [46, 17, 18, 16, 38, 37, 36], '시스템기획': [34, 33, 49, 48, 24, 23, 20, 19, 13, 12], '밸런스기획': [54, 55, 52, 53], '클라이언트프로그래밍': [28, 27, 26]}
# {'서버프로그래밍': [45, 44, 41, 4], '콘텐츠기획': [35, 14, 7], '시스템기획': [32, 30, 11, 8, 6, 1], '밸런스기획': [50, 10, 9], '클라이언트프로그래밍': [43, 42, 31, 25, 3]}
#
# <h2> <strong>➢ 팀별 금주 주간 업무</strong></h2><ul> <li> <p>시스템기획</p> <ul> <li><a href="http://127.0.0.1/redmine/issues/32">#32</a> 퀘스트 시스템 기획 (진행)</li> <ul> <li><a href="http://127.0.0.1/redmine/issues/34">#34</a> 에픽 퀘스트 시스템 기획 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/33">#33</a> 단발성 퀘스트 시스템 기획 (진행)</li> </ul> <li><a href="http://127.0.0.1/redmine/issues/30">#30</a> 메인화면 UI 기획 (진행)</li> <ul> <li><a href="http://127.0.0.1/redmine/issues/49">#49</a> 바 UI 기획 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/48">#48</a> 버튼 UI 기획 (진행)</li> </ul> <li><a href="http://127.0.0.1/redmine/issues/11">#11</a> 캐릭터 능력치 기획 (진행)</li> <ul> <li><a href="http://127.0.0.1/redmine/issues/13">#13</a> 캐릭터 2차 능력치 기획 (진행)</li> <ul> <li><a href="http://127.0.0.1/redmine/issues/24">#24</a> Defence 정의 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/23">#23</a> Attack Rating 정의 (진행)</li> </ul> <li><a href="http://127.0.0.1/redmine/issues/12">#12</a> 캐릭터 1차 능력치 기획 (진행)</li> <ul> <li><a href="http://127.0.0.1/redmine/issues/20">#20</a> Dexterity 정의 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/19">#19</a> Strength 정의 (진행)</li> </ul> </ul> <li><a href="http://127.0.0.1/redmine/issues/8">#8</a> 소모성 아이템 시스템 기획 (진행)</li> <ul> </ul> <li><a href="http://127.0.0.1/redmine/issues/6">#6</a> 소모성 아이템 UI 기획 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/1">#1</a> 클라이언트 접속 불가 문제 (진행)</li> </ul> </li> <li> <p>콘텐츠기획</p> <ul> <li><a href="http://127.0.0.1/redmine/issues/35">#35</a> 퀘스트 보상 시스템 기획 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/14">#14</a> 세계관 및 시나리오 하이컨셉 (진행)</li> <ul> <li><a href="http://127.0.0.1/redmine/issues/17">#17</a> 주요 세력 설정 (진행)</li> <ul> <li><a href="http://127.0.0.1/redmine/issues/46">#46</a> 주요 세력: 일곱 개의 기둥 (진행)</li> </ul> <li><a href="http://127.0.0.1/redmine/issues/18">#18</a> 주요 배경 설정 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/16">#16</a> 주요 인물 설정 (진행)</li> </ul> <li><a href="http://127.0.0.1/redmine/issues/7">#7</a> 소모성 아이템 콘텐츠 기획 (진행)</li> <ul> <li><a href="http://127.0.0.1/redmine/issues/38">#38</a> 소모성 아이템: 섬광탄 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/37">#37</a> 소모성 아이템: 폭탄 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/36">#36</a> 소모성 아이템: 곰덫 (진행)</li> </ul> </ul> </li> <li> <p>밸런스기획</p> <ul> <li><a href="http://127.0.0.1/redmine/issues/50">#50</a> 전체 밸런스 기획 (진행)</li> <ul> <li><a href="http://127.0.0.1/redmine/issues/52">#52</a> 장비 아이템 밸런스 기획 (진행)</li> <ul> <li><a href="http://127.0.0.1/redmine/issues/55">#55</a> 장비 아이템 밸런스 테이블 작성 (진행)</li> </ul> <li><a href="http://127.0.0.1/redmine/issues/53">#53</a> 캐릭터 능력치 밸런스 기획 (진행)</li> <ul> <li><a href="http://127.0.0.1/redmine/issues/54">#54</a> 캐릭터 능력치 밸런스 테이블 작성 (진행)</li> </ul> </ul> <li><a href="http://127.0.0.1/redmine/issues/10">#10</a> 소모성 아이템 파라미터 기획 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/9">#9</a> 소모성 아이템 성장 시스템 기획 (진행)</li> </ul> </li> <li> <p>클라이언트프로그래밍</p> <ul> <li><a href="http://127.0.0.1/redmine/issues/43">#43</a> ERROR 37 메시지와 함께 클라이언트 크래시 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/42">#42</a> 소모성 아이템이 드랍되지 않는 문제 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/31">#31</a> 메인화면 UI 구현 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/25">#25</a> 코드 스타일 정리 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/3">#3</a> 장비 인벤토리 UI 구현 (진행)</li> <ul> <li><a href="http://127.0.0.1/redmine/issues/28">#28</a> 장비 분해 기능 구현 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/27">#27</a> 장비 강화 기능 구현 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/26">#26</a> 장비 정렬 기능 구현 (진행)</li> </ul> </ul> </li> <li> <p>서버프로그래밍</p> <ul> <li><a href="http://127.0.0.1/redmine/issues/45">#45</a> 클라이언트와 서버 버전이 맞지 않는 문제 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/44">#44</a> 퀘스트 보상이 2개씩 들어오는 문제 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/41">#41</a> 퀘스트 보상이 들어오지 않는 문제 (진행)</li> <li><a href="http://127.0.0.1/redmine/issues/4">#4</a> 클라이언트 접속 불가 문제 지원 (진행)</li> </ul ...

# %%
issues
# Out:
# {'밸런스기획': [[55, '장비 아이템 밸런스 테이블 작성', '유화영', '진행'],
#   [54, '캐릭터 능력치 밸런스 테이블 작성', '유화영', '진행'],
#   [53, '캐릭터 능력치 밸런스 기획', '유화영', '진행'],
#   [52, '장비 아이템 밸런스 기획', '유화영', '진행'],
#   [50, '전체 밸런스 기획', '유화영', '진행'],
#   [10, '소모성 아이템 파라미터 기획', '유화영', '진행'],
#   [9, '소모성 아이템 성장 시스템 기획', '유화영', '진행']],
#  '시스템기획': [[49, '바 UI 기획', '서달수', '진행'],
#   [48, '버튼 UI 기획', '서달수', '진행'],
#   [34, '에픽 퀘스트 시스템 기획', '장인목', '진행'],
#   [33, '단발성 퀘스트 시스템 기획', '장인목', '진행'],
#   [32, '퀘스트 시스템 기획', '장인목', '진행'],
#   [30, '메인화면 UI 기획', '서달수', '진행'],
#   [24, 'Defence 정의', '장인목', '진행'],
#   [23, 'Attack Rating 정의', '장인목', '진행'],
#   [20, 'Dexterity 정의', '백무연', '진행'],
#   [19, 'Strength 정의', '백무연', '진행'],
#   [13, '캐릭터 2차 능력치 기획', '장인목', '진행'],
#   [12, '캐릭터 1차 능력치 기획', '백무연', '진행'],
#   [11, '캐릭터 능력치 기획', '백무연', '진행'],
#   [8, '소모성 아이템 시스템 기획', '장인목', '진행'],
#   [6, '소모성 아이템 UI 기획', '서달수', '진행'],
#   [1, '클라이언트 접속 불가 문제', '백무연', '진행']],
#  '콘텐츠기획': [[46, '주요 세력: 일곱 개의 기둥', '진미화', '진행'],
#   [38, '소모성 아이템: 섬광탄', '진미화', '진행'],
#   [37, '소모성 아이템: 폭탄', '반규린', '진행'],
#   [36, '소모성 아이템: 곰덫', '반규린', '진행'],
#   [35, '퀘스트 보상 시스템 기획', '반규린', '진행'],
#   [18, '주요 배경 설정', '진미화', '진행'],
#   [17, '주요 세력 설정', '진미화', '진행'],
#   [16, '주요 인물 설정', '진미화', '진행'],
#   [14, '세계관 및 시나리오 하이컨셉', '진미화', '진행'],
#   [7, '소모성 아이템 콘텐츠 기획', '반규린', '진행']],
#  '서버프로그래밍': [[45, '클라이언트와 서버 버전이 맞지 않는 문제', '구연기', '진행'],
#   [44, '퀘스트 보상이 2개씩 들어오는 문제', '구연기', '진행'],
#   [41, '퀘스트 보상이 들어오지 않는 문제', '이해은', '진행'],
#   [4, '클라이언트 접속 불가 문제 지원', '이해은', '진행']],
#  '클라이언트프로그래밍': [[43, 'ERROR 37 메시지와 함께 클라이언트 크래시', '임파초', '진행'],
#   [42, '소모성 아이템이 드랍되지 않는 문제', '이인성', '진행'],
#   [31, '메인화면 UI 구현', '임파초', '진행'],
#   [28, '장비 분해 기능 구현', '이인성', '진행'],
#   [27, '장비 강화 기능 구현', '이인성', '진행'],
#   [26, '장비 정렬 기능 구현', '이인성', '진행'],
#   [25, '코드 스타일 정리', '임파초', '진행'],
#   [3, '장비 인벤토리 UI 구현', '임파초', '진행']]}
